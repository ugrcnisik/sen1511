# %% [markdown]
# If you are running this on Google Colab, you need to uncomment (remove the `#`) and execute the following lines to install the Pyomo package, the solver, and some helper tools. If you are running this on Binder or elsewhere (e.g. your own computer) you can ignore this.

# %%
 # !pip install pyomo==6.4.1
 # !pip install "git+https://github.com/sjpfenninger/sen1511.git#egg=sen1511utils&subdirectory=sen1511utils"

 # !wget https://repo.anaconda.com/miniconda/Miniconda3-py37_4.12.0-Linux-x86_64.sh
 # !chmod +x Miniconda3-py37_4.12.0-Linux-x86_64.sh
 # !bash ./Miniconda3-py37_4.12.0-Linux-x86_64.sh -b -f -p /usr/local/
 # !conda install -y -c conda-forge ipopt
# Out:
# Requirement already satisfied: pyomo==6.4.1 in /Users/ugurcanisik/opt/anaconda3/lib/python3.9/site-packages (6.4.1)
# Requirement already satisfied: ply in /Users/ugurcanisik/opt/anaconda3/lib/python3.9/site-packages (from pyomo==6.4.1) (3.11)
# Collecting sen1511utils
#   Cloning https://github.com/sjpfenninger/sen1511.git to /private/var/folders/w5/dk6ny3710vz1s6v9cv1gv6jc0000gn/T/pip-install-s5fmost2/sen1511utils_843610c85009443c8f5e1633f2c868c1
#   Running command git clone -q https://github.com/sjpfenninger/sen1511.git /private/var/folders/w5/dk6ny3710vz1s6v9cv1gv6jc0000gn/T/pip-install-s5fmost2/sen1511utils_843610c85009443c8f5e1633f2c868c1
#   xcrun: error: invalid active developer path (/Library/Developer/CommandLineTools), missing xcrun at: /Library/Developer/CommandLineTools/usr/bin/xcrun
# WARNING: Discarding git+https://github.com/sjpfenninger/sen1511.git#egg=sen1511utils&subdirectory=sen1511utils. Command errored out with exit status 1: git clone -q https://github.com/sjpfenninger/sen1511.git /private/var/folders/w5/dk6ny3710vz1s6v9cv1gv6jc0000gn/T/pip-install-s5fmost2/sen1511utils_843610c85009443c8f5e1633f2c868c1 Check the logs for full command output.
# ERROR: Could not find a version that satisfies the requirement sen1511utils (unavailable) (from versions: none)
# ERROR: No matching distribution found for sen1511utils (unavailable)
# zsh:1: command not found: wget
# chmod: Miniconda3-py37_4.12.0-Linux-x86_64.sh: No such file or directory
# bash: ./Miniconda3-py37_4.12.0-Linux-x86_64.sh: No such file or directory
# Collecting package metadata (current_repodata.json): done
# Solving environment: failed with initial frozen solve. Retrying with flexible solve.
# Solving environment: failed with repodata from current_repodata.json, will retry with next repodata source.
# Collecting package metadata (repodata.json): done
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.13.0
#   latest version: 4.14.0
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# ## Package Plan ##
#
#   environment location: /Users/ugurcanisik/opt/anaconda3
#
#   added / updated specs:
#     - ipopt
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     ampl-mp-3.1.0              |    ha90c164_1003         1.1 MB  conda-forge
#     cctools-973.0.1            |       hd9211c8_2          17 KB  conda-forge
#     cctools_osx-64-973.0.1     |       h3e07e27_2         2.0 MB  conda-forge
#     conda-4.14.0               |   py39h6e9494a_0        1022 KB  conda-forge
#     conda-build-3.22.0         |   py39h6e9494a_2         569 KB  conda-forge
#     ipopt-3.12.12              |    h4cdd4fb_1006         2.1 MB  conda-forge
#     ld64-609                   |       hd2e7500_2          15 KB  conda-forge
#     ld64_osx-64-609            |       h2487922_2         1.5 MB  conda-forge
#     ldid-2.1.2                 |       h6a69015_3          55 KB  conda-forge
#     libblas-3.9.0              |     12_osx64_mkl          12 KB  conda-forge
#     liblapack-3.9.0            |     12_osx64_mkl          12 KB  conda-forge
#     libllvm12-12.0.1           |       hd011deb_2        24.1 MB  conda-forge
#     metis-5.1.0                |    h2e338ed_1006         4.1 MB  conda-forge
#     mumps-include-5.2.1        |      h694c41f_11          24 KB  conda-forge
#     mumps-seq-5.2.1            |       h5323e2b_3         3.0 MB  conda-forge
#     patch-2.7.6                |    hbcf498f_1002         133 KB  conda-forge
#     python_abi-3.9             |           2_cp39           4 KB  conda-forge
#     scotch-6.0.8               |       h703c93e_1         1.2 MB  conda-forge
#     tapi-1100.0.11             |       h9ce4665_0         196 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:        41.0 MB
#
# The following NEW packages will be INSTALLED:
#
#   ampl-mp            conda-forge/osx-64::ampl-mp-3.1.0-ha90c164_1003
#   cctools            conda-forge/osx-64::cctools-973.0.1-hd9211c8_2
#   cctools_osx-64     conda-forge/osx-64::cctools_osx-64-973.0.1-h3e07e27_2
#   ipopt              conda-forge/osx-64::ipopt-3.12.12-h4cdd4fb_1006
#   ld64               conda-forge/osx-64::ld64-609-hd2e7500_2
#   ld64_osx-64        conda-forge/osx-64::ld64_osx-64-609-h2487922_2
#   ldid               conda-forge/osx-64::ldid-2.1.2-h6a69015_3
#   libblas            conda-forge/osx-64::libblas-3.9.0-12_osx64_mkl
#   liblapack          conda-forge/osx-64::liblapack-3.9.0-12_osx64_mkl
#   libllvm12          conda-forge/osx-64::libllvm12-12.0.1-hd011deb_2
#   metis              conda-forge/osx-64::metis-5.1.0-h2e338ed_1006
#   mumps-include      conda-forge/osx-64::mumps-include-5.2.1-h694c41f_11
#   mumps-seq          conda-forge/osx-64::mumps-seq-5.2.1-h5323e2b_3
#   patch              conda-forge/osx-64::patch-2.7.6-hbcf498f_1002
#   python_abi         conda-forge/osx-64::python_abi-3.9-2_cp39
#   scotch             conda-forge/osx-64::scotch-6.0.8-h703c93e_1
#   tapi               conda-forge/osx-64::tapi-1100.0.11-h9ce4665_0
#
# The following packages will be UPDATED:
#
#   conda              pkgs/main::conda-4.13.0-py39hecd8cb5_0 --> conda-forge::conda-4.14.0-py39h6e9494a_0
#   conda-build        pkgs/main::conda-build-3.21.5-py39hec~ --> conda-forge::conda-build-3.22.0-py39h6e9494a_2
#
#
#
# Downloading and Extracting Packages
# python_abi-3.9       | 4 KB      | ##################################### | 100%
# metis-5.1.0          | 4.1 MB    | ##################################### | 100%
# libllvm12-12.0.1     | 24.1 MB   | ##################################### | 100%
# ld64_osx-64-609      | 1.5 MB    | ##################################### | 100%
# scotch-6.0.8         | 1.2 MB    | ##################################### | 100%
# ipopt-3.12.12        | 2.1 MB    | ##################################### | 100%
# mumps-seq-5.2.1      | 3.0 MB    | ##################################### | 100%
# patch-2.7.6          | 133 KB    | ##################################### | 100%
# cctools_osx-64-973.0 | 2.0 MB    | ##################################### | 100%
# ld64-609             | 15 KB     | ##################################### | 100%
# cctools-973.0.1      | 17 KB     | ##################################### | 100%
# ldid-2.1.2           | 55 KB     | ##################################### | 100%
# mumps-include-5.2.1  | 24 KB     | ##################################### | 100%
# libblas-3.9.0        | 12 KB     | ##################################### | 100%
# conda-4.14.0         | 1022 KB   | ##################################### | 100%
# tapi-1100.0.11       | 196 KB    | ##################################### | 100%
# conda-build-3.22.0   | 569 KB    | ##################################### | 100%
# liblapack-3.9.0      | 12 KB     | ##################################### | 100%
# ampl-mp-3.1.0        | 1.1 MB    | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done

# %%
import pyomo.environ as pyo

from sen1511utils import summarise_results

# %% [markdown]
# # Assignment 4 - Nonlinear programming (NLP)

# %% [markdown]
# ## NUMBER.a)

# %%
m = pyo.ConcreteModel(name = "Economic dispatch with quadratic cost functions")
m.dual = pyo.Suffix(direction=pyo.Suffix.IMPORT)

##
# 1. Decision variables
##

m.PG1 = pyo.Var(domain=pyo.NonNegativeReals)
m.PG2 = pyo.Var(domain=pyo.NonNegativeReals)
m.PG3 = pyo.Var(domain=pyo.NonNegativeReals)

##
# 2. Objective function
##

cost_0 = 10 +    1 * m.PG1 + 0.5 *  0.1 * m.PG1**2
cost_1 = 20 +  1.1 * m.PG2 + 0.5 * 0.05 * m.PG2**2
cost_2 = 20 + 1.25 * m.PG3 + 0.5 *  0.1 * m.PG3**2

m.cost = pyo.Objective(
    expr = cost_0 + cost_1 + cost_2,
    sense = pyo.minimize,
)

##
# 3. Constraints
##

# For the case of 80 MW demand (other cases: 5 MW, 30 MW)
m.demand = pyo.Constraint(expr = m.PG1 + m.PG2 + m.PG3 == 80)

m.pg1_max = pyo.Constraint(expr = m.PG1 <= 30)
m.pg2_max = pyo.Constraint(expr = m.PG2 <= 40)
m.pg3_max = pyo.Constraint(expr = m.PG3 <= 50)

# Solve the problem
solver = pyo.SolverFactory('ipopt')
solver.solve(m)
# Out:
# {'Problem': [{'Lower bound': -inf, 'Upper bound': inf, 'Number of objectives': 1, 'Number of constraints': 4, 'Number of variables': 3, 'Sense': 'unknown'}], 'Solver': [{'Status': 'ok', 'Message': 'Ipopt 3.14.2\\x3a Optimal Solution Found', 'Termination condition': 'optimal', 'Id': 0, 'Error rc': 0, 'Time': 0.09206938743591309}], 'Solution': [OrderedDict([('number of solutions', 0), ('number of solutions displayed', 0)])]}

# %%
summarise_results(m)
# Out:
# <style type="text/css">
# </style>
# <table id="T_e5d32_" style='display:inline'>
#   <caption>Objective</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Name</th>
#       <th class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e5d32_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e5d32_row0_col0" class="data row0 col0" >cost</td>
#       <td id="T_e5d32_row0_col1" class="data row0 col1" >218.843750</td>
#     </tr>
#   </tbody>
# </table>
#    <style type="text/css">
# </style>
# <table id="T_28ea2_" style='display:inline'>
#   <caption>Variables</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Name</th>
#       <th class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_28ea2_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_28ea2_row0_col0" class="data row0 col0" >PG1</td>
#       <td id="T_28ea2_row0_col1" class="data row0 col1" >21.250000</td>
#     </tr>
#     <tr>
#       <th id="T_28ea2_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_28ea2_row1_col0" class="data row1 col0" >PG2</td>
#       <td id="T_28ea2_row1_col1" class="data row1 col1" >40.000000</td>
#     </tr>
#     <tr>
#       <th id="T_28ea2_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_28ea2_row2_col0" class="data row2 col0" >PG3</td>
#       <td id="T_28ea2_row2_col1" class="data row2 col1" >18.750000</td>
#     </tr>
#   </tbody>
# </table>
#    <style type="text/css">
# </style>
# <table id="T_1559f_" style='display:inline'>
#   <caption>Constraints</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Name</th>
#       <th class="col_heading level0 col1" >Expression</th>
#       <th class="col_heading level0 col2" >Value</th>
#       <th class="col_heading level0 col3" >Shadow price</th>
#       <th class="col_heading level0 col4" >Binding</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1559f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_1559f_row0_col0" class="data row0 col0" >demand</td>
#       <td id="T_1559f_row0_col1" class="data row0 col1" >PG1 + PG2 + PG3  ==  80</td>
#       <td id="T_1559f_row0_col2" class="data row0 col2" >80.000000</td>
#       <td id="T_1559f_row0_col3" class="data row0 col3" >3.125000</td>
#       <td id="T_1559f_row0_col4" class="data row0 col4" >True</td>
#     </tr>
#     <tr>
#       <th id="T_1559f_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_1559f_row1_col0" class="data row1 col0" >pg1_max</td>
#       <td id="T_1559f_row1_col1" class="data row1 col1" >PG1  <=  30</td>
#       <td id="T_1559f_row1_col2" class="data row1 col2" >21.250000</td>
#       <td id="T_1559f_row1_col3" class="data row1 col3" >-0.000000</td>
#       <td id="T_1559f_row1_col4" class="data row1 col4" >False</td>
#     </tr>
#     <tr>
#       <th id="T_1559f_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_1559f_row2_col0" class="data row2 col0" >pg2_max</td>
#       <td id="T_1559f_row2_col1" class="data row2 col1" >PG2  <=  40</td>
#       <td id="T_1559f_row2_col2" class="data row2 col2" >40.000000</td>
#       <td id="T_1559f_row2_col3" class="data row2 col3" >-0.025000</td>
#       <td id="T_1559f_row2_col4" class="data row2 col4" >True</td>
#     </tr>
#     <tr>
#       <th id="T_1559f_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_1559f_row3_col0" class="data row3 col0" >pg3_max</td>
#       <td id="T_1559f_row3_col1" class="data row3 col1" >PG3  <=  50</td>
#       <td id="T_1559f_row3_col2" class="data row3 col2" >18.750000</td>
#       <td id="T_1559f_row3_col3" class="data row3 col3" >-0.000000</td>
#       <td id="T_1559f_row3_col4" class="data row3 col4" >False</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# 💡 As usual, you could use Python to automate - and make it easier to extend this to a larger problem with many more power plants. For example, you might specify the cost function as an actual Python function and and sum it up with `sum()` in the objective:
#
# ```python
# PG = [m.PG1, m.PG2, m.PG3]
# C = [10, 20, 20]
# a = [1, 1.1, 1.25]
# b = [0.1, 0.05, 0.1]
#
# def cost(i):
#     return C[i] + a[i] * PG[i] + 0.5 * b[i] * PG[i]**2
#
# m.cost = pyo.Objective(
#     expr = sum(cost[i] for i in range(3)),
#     sense = pyo.minimize,
# )
# ```
#
# </div>

# %% [markdown]
# ## NUMBER.b)

# %%
m = pyo.ConcreteModel(name = "Economic dispatch with quadratic cost functions and elastic demand")
m.dual = pyo.Suffix(direction=pyo.Suffix.IMPORT)

##
# 1. Decision variables
##

# Generation
m.PG1 = pyo.Var(domain=pyo.NonNegativeReals)
m.PG2 = pyo.Var(domain=pyo.NonNegativeReals)
m.PG3 = pyo.Var(domain=pyo.NonNegativeReals)

# Demand
m.PD1 = pyo.Var(domain=pyo.NonNegativeReals)
m.PD2 = pyo.Var(domain=pyo.NonNegativeReals)

##
# 2. Objective function
##

PG = [m.PG1, m.PG2, m.PG3]
PD = [m.PD1, m.PD2]
C = [10, 20, 20]
a = [1, 1.1, 1.25]
b = [0.1, 0.05, 0.1]
ad = [55, 50]
bd = [-0.2, -0.1]

def cost(i):
    return C[i] + a[i] * PG[i] + 0.5 * b[i] * PG[i]**2

def util (j):
    return  ad[j]* PD[j]  +   bd[j] * PD[j]**2

m.SW = pyo.Objective(
    expr =  util (0) + util (1) - (cost(0) + cost(1) + cost(2)),
    sense = pyo.maximize,
)

##
# 3. Constraints
##

# For the case of 80 MW demand (other cases: 5 MW, 30 MW)
m.demand = pyo.Constraint(expr = m.PG1 + m.PG2 + m.PG3 == m.PD1 + m.PD2)

m.pg1_max = pyo.Constraint(expr = m.PG1 <= 30)
m.pg2_max = pyo.Constraint(expr = m.PG2 <= 40)
m.pg3_max = pyo.Constraint(expr = m.PG3 <= 50)
m.pd1_max = pyo.Constraint(expr = m.PD1 <= 300)
m.pd2_max = pyo.Constraint(expr = m.PD2 <= 350)


# Solve the problem
solver = pyo.SolverFactory('ipopt')
solver.solve(m)
# Out:
# {'Problem': [{'Lower bound': -inf, 'Upper bound': inf, 'Number of objectives': 1, 'Number of constraints': 6, 'Number of variables': 5, 'Sense': 'unknown'}], 'Solver': [{'Status': 'ok', 'Message': 'Ipopt 3.14.2\\x3a Optimal Solution Found', 'Termination condition': 'optimal', 'Id': 0, 'Error rc': 0, 'Time': 0.03775835037231445}], 'Solution': [OrderedDict([('number of solutions', 0), ('number of solutions displayed', 0)])]}

# %%
summarise_results(m)
# Out:
# <style type="text/css">
# </style>
# <table id="T_30995_" style='display:inline'>
#   <caption>Objective</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Name</th>
#       <th class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_30995_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_30995_row0_col0" class="data row0 col0" >SW</td>
#       <td id="T_30995_row0_col1" class="data row0 col1" >4864.333371</td>
#     </tr>
#   </tbody>
# </table>
#    <style type="text/css">
# </style>
# <table id="T_77a1a_" style='display:inline'>
#   <caption>Variables</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Name</th>
#       <th class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_77a1a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_77a1a_row0_col0" class="data row0 col0" >PG1</td>
#       <td id="T_77a1a_row0_col1" class="data row0 col1" >30.000000</td>
#     </tr>
#     <tr>
#       <th id="T_77a1a_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_77a1a_row1_col0" class="data row1 col0" >PG2</td>
#       <td id="T_77a1a_row1_col1" class="data row1 col1" >40.000000</td>
#     </tr>
#     <tr>
#       <th id="T_77a1a_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_77a1a_row2_col0" class="data row2 col0" >PG3</td>
#       <td id="T_77a1a_row2_col1" class="data row2 col1" >50.000000</td>
#     </tr>
#     <tr>
#       <th id="T_77a1a_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_77a1a_row3_col0" class="data row3 col0" >PD1</td>
#       <td id="T_77a1a_row3_col1" class="data row3 col1" >48.333334</td>
#     </tr>
#     <tr>
#       <th id="T_77a1a_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_77a1a_row4_col0" class="data row4 col0" >PD2</td>
#       <td id="T_77a1a_row4_col1" class="data row4 col1" >71.666667</td>
#     </tr>
#   </tbody>
# </table>
#    <style type="text/css">
# </style>
# <table id="T_bf666_" style='display:inline'>
#   <caption>Constraints</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Name</th>
#       <th class="col_heading level0 col1" >Expression</th>
#       <th class="col_heading level0 col2" >Value</th>
#       <th class="col_heading level0 col3" >Shadow price</th>
#       <th class="col_heading level0 col4" >Binding</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bf666_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_bf666_row0_col0" class="data row0 col0" >demand</td>
#       <td id="T_bf666_row0_col1" class="data row0 col1" >PG1 + PG2 + PG3  ==  PD1 + PD2</td>
#       <td id="T_bf666_row0_col2" class="data row0 col2" >0.000000</td>
#       <td id="T_bf666_row0_col3" class="data row0 col3" >-35.666667</td>
#       <td id="T_bf666_row0_col4" class="data row0 col4" >True</td>
#     </tr>
#     <tr>
#       <th id="T_bf666_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_bf666_row1_col0" class="data row1 col0" >pg1_max</td>
#       <td id="T_bf666_row1_col1" class="data row1 col1" >PG1  <=  30</td>
#       <td id="T_bf666_row1_col2" class="data row1 col2" >30.000000</td>
#       <td id="T_bf666_row1_col3" class="data row1 col3" >31.666666</td>
#       <td id="T_bf666_row1_col4" class="data row1 col4" >True</td>
#     </tr>
#     <tr>
#       <th id="T_bf666_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_bf666_row2_col0" class="data row2 col0" >pg2_max</td>
#       <td id="T_bf666_row2_col1" class="data row2 col1" >PG2  <=  40</td>
#       <td id="T_bf666_row2_col2" class="data row2 col2" >40.000000</td>
#       <td id="T_bf666_row2_col3" class="data row2 col3" >32.566666</td>
#       <td id="T_bf666_row2_col4" class="data row2 col4" >True</td>
#     </tr>
#     <tr>
#       <th id="T_bf666_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_bf666_row3_col0" class="data row3 col0" >pg3_max</td>
#       <td id="T_bf666_row3_col1" class="data row3 col1" >PG3  <=  50</td>
#       <td id="T_bf666_row3_col2" class="data row3 col2" >50.000000</td>
#       <td id="T_bf666_row3_col3" class="data row3 col3" >29.416666</td>
#       <td id="T_bf666_row3_col4" class="data row3 col4" >True</td>
#     </tr>
#     <tr>
#       <th id="T_bf666_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_bf666_row4_col0" class="data row4 col0" >pd1_max</td>
#       <td id="T_bf666_row4_col1" class="data row4 col1" >PD1  <=  300</td>
#       <td id="T_bf666_row4_col2" class="data row4 col2" >48.333334</td>
#       <td id="T_bf666_row4_col3" class="data row4 col3" >0.000000</td>
#       <td id="T_bf666_row4_col4" class="data row4 col4" >False</td>
#     </tr>
#     <tr>
#       <th id="T_bf666_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_bf666_row5_col0" class="data row5 col0" >pd2_max</td>
#       <td id="T_bf666_row5_col1" class="data row5 col1" >PD2  <=  350</td>
#       <td id="T_bf666_row5_col2" class="data row5 col2" >71.666667</td>
#       <td id="T_bf666_row5_col3" class="data row5 col3" >0.000000</td>
#       <td id="T_bf666_row5_col4" class="data row5 col4" >False</td>
#     </tr>
#   </tbody>
# </table>
